# %%
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm
import json
import time
import random
import os
import logging
from datetime import datetime
import os
import sys
import requests

# %%
# json 파일을 불러와서 딕셔너리로 변환
with open("./list/list_data.json", "r", encoding="utf-8") as f:
    list_dic = json.load(f)
list_dic

# %%
class ShortRestException(Exception):
    pass
class LongRestException(Exception):
    pass

def crawl_html(session, url):
    """
        url주소에서 json을 가져와 파일을 저장합니다.
        :session: 세션
        :url: 불러오고자 하는 url
        :return:
    """
    headers = {
        "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36 Edg/120.0.0.0",
        "Accept-Language" : "ko,en;q=0.9,en-US;q=0.8"
    }

    response = session.get(url,timeout=10,headers=headers)
    if (response.status_code==200):
        pass
    elif (response.status_code==408):
        raise ShortRestException(response.status_code)
    elif (response.status_code in [429,500]):
        raise LongRestException(response.status_code)
    else:
        return -1

    soup = BeautifulSoup(response.text, 'html.parser')
    return str(soup)

# %%
def crawl_json(session, lecture_id):
    """
    url주소에서 json을 가져와 파일을 저장합니다.
    :session: 세션
    :lecture_id: 불러올 강의 id
    :key_String:대분류이름
    :subcategory_id:대분류id
    :folder_path:저장될폴더주소
    :return: -1 실패, 성공시 데이터 dictionary 반환
    """
    json_dic = {}
    # 가격 및 커리큘럼
    url = f"https://www.inflearn.com/api/v2/review/course/{lecture_id}?pageSize=10000&pageNumber=1&isNew=true"
    # headers = {
    #     "Accept": "application/json, text/plain, */*",
    #     "Authorization": "Basic QlljUTI2VUZkNXFWWnJwMnRiOW9EYlc4Mkl3aUVKb3dHY2Q1MFpiZTpPMEpQM2JRellJNG1ac3pwRVljMllWWjV3UDJQSHRGYzR0T0dnbmdSekJpN0pmVTVMaExuY0Z4QVFLRTFtNUgzM1R2VFhtMXFpUVpnNjBXMHlib2l0aVdjSmNqdm9LUEoyTldRcFhVd3BPWHpZaGV0cE5RNGo4em9wTE9kYUVMTw==",
    #     "Content-Type": "application/json"
    # }
    
    response = session.get(url,timeout=10)
    if (response.status_code==200):
        pass
    elif (response.status_code==408):
        raise ShortRestException(response.status_code)
    elif (response.status_code in [429,500]):
        raise LongRestException(response.status_code)
    else:
        return -1

    data = response.json()
    json_dic.update(data)

    return json_dic

# %%
for idx, (lecture_id, item) in tqdm(enumerate(list_dic.items())):
    url = item["url"]
    # print(url)
    session = requests.session()
    # print(crawl_html(session, url))
    dic = crawl_json(session, lecture_id)
    print(dic)








    break
# Out:
# 0it [00:00, ?it/s]
# {'statusCode': 'OK', 'message': '', 'data': {'pageNumber': 1, 'pageSize': 10000, 'totalCount': 80, 'totalPage': 1, 'items': [{'id': 16103, 'star': 5, 'body': '저는 외국인이고 항상 웹을 어디서부터 배워야하냐고 고민했었습니다. 이 강의 덕분에 벌써 자기 프러젝트를 시작해보렸어요. 설명이 잘 되어 있고 동기도 많이 있어서요~ 감사합니다~~', 'userName': 'shamshodjon23.08', 'createdAt': '2020-05-10 11:26:45', 'recommendCount': 4, 'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png', 'isRecommended': False, 'isEditable': False, 'comments': [], 'userId': 205393, 'lectureProgress': '100.00', 'postId': 34411, 'userSlug': '', 'userRatingAverage': '5.0', 'userCourseReviewCount': 3}, {'id': 26277, 'star': 5, 'body': '선생님.. 교수님... 정말감사드립니다\n기본이 정말 중요하다는것을 다시한번 깨닫게됬고\n이러한 양질의 강의가 무료라는것에 정말 너무 감사드리고\n너무 쉽게 배울수있게 해주셔서 너무 감사드립니다\n정말 강의 보면서 많이 감탄했습니다.\n정말 감사드립니다 진심으로요..', 'userName': '김태희', 'createdAt': '2020-11-10 01:40:54', 'recommendCount': 1, 'userThumbnailUrl': 'https://cdn.inflearn.com/public/users/thumbnails/116403/765a7be4-a635-42a2-a40e-26a8db91269b', 'isRecommended': False, 'isEditable': False, 'comments': [], 'userId': 116403, 'lectureProgress': '72.73', 'postId': 89468, 'userSlug': '김태희', 'userRatingAverage': '5.0', 'userCourseReviewCount': 10}, {'id': 134720, 'star': 5, 'body': '프로그래밍을 하는데 있어서 생각하는 흐름을 알려주시고 웹 애플리케이션이 동작하는 원리를 알려주셔서 너무 좋았어요! 무료로 이런 최고의 강의를 해주셔서 너무 감사드립니다 egoing 짱입니다!!!:)', 'userName': '김재윤', 'createdAt': '2024-01-01 13:26:35', 'recommendCount': 0, 'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png', 'isRecommended': False, 'isEditable': False, 'comments': [], 'userId': 1245447, 'lectureProgress': '84.85', 'userSlug': '', 'userRatingAverage': '5.0', 'userCourseReviewCount': 1}, {'id': 127247, 'star': 5, 'body': '친절하고 알아듣기 쉽게 설명해주셨습니다', 'userName': 'wsim', 'createdAt': '2023-09-06 17:17:39', 'recommendCount': 0, 'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png', 'isRecommended': False, 'isEditable': False, 'comments': [], 'userId': 631076, 'lectureProgress': '100.00', 'postId': 1005847, 'userSlug': 'wsim', 'userRatingAverage': '5.0', 'userCourseReviewCount': 8}, {'id': 124221, 'star': 5, 'body': '잘 들었습니다.', 'userName': '최준혁', 'createdAt': '2023-07-18 15:59:40', 'recommendCount': 0, 'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png', 'isRecommended': False, 'isEditable': False, 'comments': [], 'userId': 719688, 'lectureProgress': '39.39', 'postId': 946389, 'userSlug': '', 'userRatingAverage': '5.0', 'userCourseReviewCount': 1}, {'id': 117468, 'star': 5, 'body': '재밌게 잘 들었습니다.', 'userName': 'skduddl789', 'createdAt': '2023-04-07 10:35:00', 'recommendCount': 0, 'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png', 'isRecommended': False, 'isEditable': False, 'comments': [], 'userId': 328697, 'lectureProgress': '100.00', 'postId': 839014, 'userSlug': '', 'userRatingAverage': '5.0', 'userCourseReviewCount': 1}, {'id': 115250, 'star': 5, 'body': '열심히 보고 있어요!', 'userName': '문지예', 'createdAt': '2023-03-07 00:48:46', 'recommendCount': 0, 'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png', 'isRecommended': False, 'isEditable': False, 'comments': [], 'userId': 1130255, 'lectureProgress': '100.00', 'postId': 806348, 'userSlug': '', 'userRatingAverage': '5.0', 'userCourseReviewCount': 11}, {'id': 114071, 'star': 5, 'body': '어렵지 않게 잘 설명해 주셔서 전체적인 상황과 활용법을 잘 배웠네요.', 'userName': 'skhagatha', 'createdAt': '2023-02-19 17:15:15', 'recommendCount': 0, 'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png', 'isRecommended': False, 'isEditable': False, 'comments': [], 'userId': 849215, 'lectureProgress': '81.82', 'postId': 789261, 'userSlug': '', 'userRatingAverage': '5.0', 'userCourseReviewCount': 1}, {'id': 105965, 'star': 5, 'body': '좋은강의 감사합니다!', 'userName': 'zscv119', 'createdAt': '2022-11-17 17:28:12', 'recommendCount': 0, 'userThumbnailUrl': 'https://cdn.inflearn.com/pub ...

# %%
dic
# Out:
# {'statusCode': 'OK',
#  'message': '',
#  'data': {'pageNumber': 1,
#   'pageSize': 10000,
#   'totalCount': 80,
#   'totalPage': 1,
#   'items': [{'id': 16103,
#     'star': 5,
#     'body': '저는 외국인이고 항상 웹을 어디서부터 배워야하냐고 고민했었습니다. 이 강의 덕분에 벌써 자기 프러젝트를 시작해보렸어요. 설명이 잘 되어 있고 동기도 많이 있어서요~ 감사합니다~~',
#     'userName': 'shamshodjon23.08',
#     'createdAt': '2020-05-10 11:26:45',
#     'recommendCount': 4,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 205393,
#     'lectureProgress': '100.00',
#     'postId': 34411,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 3},
#    {'id': 26277,
#     'star': 5,
#     'body': '선생님.. 교수님... 정말감사드립니다\n기본이 정말 중요하다는것을 다시한번 깨닫게됬고\n이러한 양질의 강의가 무료라는것에 정말 너무 감사드리고\n너무 쉽게 배울수있게 해주셔서 너무 감사드립니다\n정말 강의 보면서 많이 감탄했습니다.\n정말 감사드립니다 진심으로요..',
#     'userName': '김태희',
#     'createdAt': '2020-11-10 01:40:54',
#     'recommendCount': 1,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/users/thumbnails/116403/765a7be4-a635-42a2-a40e-26a8db91269b',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 116403,
#     'lectureProgress': '72.73',
#     'postId': 89468,
#     'userSlug': '김태희',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 10},
#    {'id': 134720,
#     'star': 5,
#     'body': '프로그래밍을 하는데 있어서 생각하는 흐름을 알려주시고 웹 애플리케이션이 동작하는 원리를 알려주셔서 너무 좋았어요! 무료로 이런 최고의 강의를 해주셔서 너무 감사드립니다 egoing 짱입니다!!!:)',
#     'userName': '김재윤',
#     'createdAt': '2024-01-01 13:26:35',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 1245447,
#     'lectureProgress': '84.85',
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 1},
#    {'id': 127247,
#     'star': 5,
#     'body': '친절하고 알아듣기 쉽게 설명해주셨습니다',
#     'userName': 'wsim',
#     'createdAt': '2023-09-06 17:17:39',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 631076,
#     'lectureProgress': '100.00',
#     'postId': 1005847,
#     'userSlug': 'wsim',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 8},
#    {'id': 124221,
#     'star': 5,
#     'body': '잘 들었습니다.',
#     'userName': '최준혁',
#     'createdAt': '2023-07-18 15:59:40',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 719688,
#     'lectureProgress': '39.39',
#     'postId': 946389,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 1},
#    {'id': 117468,
#     'star': 5,
#     'body': '재밌게 잘 들었습니다.',
#     'userName': 'skduddl789',
#     'createdAt': '2023-04-07 10:35:00',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 328697,
#     'lectureProgress': '100.00',
#     'postId': 839014,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 1},
#    {'id': 115250,
#     'star': 5,
#     'body': '열심히 보고 있어요!',
#     'userName': '문지예',
#     'createdAt': '2023-03-07 00:48:46',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 1130255,
#     'lectureProgress': '100.00',
#     'postId': 806348,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 11},
#    {'id': 114071,
#     'star': 5,
#     'body': '어렵지 않게 잘 설명해 주셔서 전체적인 상황과 활용법을 잘 배웠네요.',
#     'userName': 'skhagatha',
#     'createdAt': '2023-02-19 17:15:15',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 849215,
#     'lectureProgress': '81.82',
#     'postId': 789261,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 1},
#    {'id': 105965,
#     'star': 5,
#     'body': '좋은강의 감사합니다!',
#     'userName': 'zscv119',
#     'createdAt': '2022-11-17 17:28:12',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 690694,
#     'lectureProgress': '96.97',
#     'postId': 694253,
#     'userSlug': '',
#     'userRatingAverage': '4.9',
#     'userCourseReviewCount': 8},
#    {'id': 102535,
#     'star': 5,
#     'body': '좋은강의감사합니다.',
#     'userName': '권우현',
#     'createdAt': '2022-10-03 19:18:58',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 1029895,
#     'lectureProgress': '66.67',
#     'postId': 665361,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 6},
#    {'id': 101745,
#     'star': 5,
#     'body': '좋아요!!!',
#     'userName': 'ilove4622',
#     'createdAt': '2022-09-22 20:21:02',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 1029244,
#     'lectureProgress': '100.00',
#     'postId': 658138,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 2},
#    {'id': 101084,
#     'star': 5,
#     'body': '올해안에 프론트엔드 취업 목표로 필수 기초과목 수강중입니다.\n\nHTML, 자바스크립트, PHP 기초 구문과 각 언어별 차이점 등등.. 초보자도 이해하기 쉽게 설명해주셔서 너무 좋습니다.\n\n실습 따라하면서 결과물도 바로바로 확인할 수 있으니 하는 재미까지 있네요.\n\n좋은 강의 너무 감사드립니다.',
#     'userName': 'stdsic9900',
#     'createdAt': '2022-09-14 16:35:23',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 1031119,
#     'lectureProgress': '95.45',
#     'postId': 651551,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 4},
#    {'id': 100414,
#     'star': 5,
#     'body': '좋은 강의 감사합니다!',
#     'userName': '아라레',
#     'createdAt': '2022-09-06 23:19:57',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/users/thumbnails/325869/8c9c3703-75e7-478c-ad5f-7884f3033842',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 325869,
#     'lectureProgress': '6.06',
#     'postId': 645382,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 177},
#    {'id': 99801,
#     'star': 5,
#     'body': '생활코딩 GOAT.. 언제나 알차네요 이정도 퀄에 돈을 안받는다는게 그저 놀라울 정도',
#     'userName': 'amt02927',
#     'createdAt': '2022-08-30 19:33:04',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 834982,
#     'lectureProgress': '100.00',
#     'postId': 638434,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 1},
#    {'id': 99352,
#     'star': 5,
#     'body': '강의 내용 질 모두 좋습니다',
#     'userName': 'giantcjw2',
#     'createdAt': '2022-08-25 16:32:27',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 836407,
#     'lectureProgress': '54.55',
#     'postId': 633263,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 2},
#    {'id': 99135,
#     'star': 5,
#     'body': '최고의 강의 전공자이긴 하지만 전체적인 프로그래밍 구조를 몰라서 풀스택강의 찾다가 들어봤는데 생활코딩님 강의 정주행 합니다. 굿굿',
#     'userName': '이건희',
#     'createdAt': '2022-08-22 21:34:32',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 917702,
#     'lectureProgress': '66.67',
#     'postId': 630580,
#     'userSlug': 'geonhee0503',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 2},
#    {'id': 98083,
#     'star': 5,
#     'body': '인터넷과 웹에 대한 배경지식과 역사를 배울 수 있습니다. 웹개발을 시작하기 전에, 왜 공부를 해야 되는지 한번 생각해보게 해주는 강의 입니다~!',
#     'userName': 'alvinlog',
#     'createdAt': '2022-08-10 18:26:41',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 501140,
#     'lectureProgress': '6.06',
#     'postId': 619965,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 12},
#    {'id': 90206,
#     'star': 5,
#     'body': '귀한 강의 감사합니다.',
#     'userName': '똘똘이스머프',
#     'createdAt': '2022-05-27 16:35:08',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/users/thumbnails/672128/eff419e4-57df-4d9c-b98d-90bc68d3e33d',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 672128,
#     'lectureProgress': '100.00',
#     'postId': 548135,
#     'userSlug': 'hyongsu44',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 626},
#    {'id': 87392,
#     'star': 5,
#     'body': '감사합니다~!!',
#     'userName': 'everick9',
#     'createdAt': '2022-05-04 12:00:13',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 433714,
#     'lectureProgress': '7.58',
#     'postId': 527391,
#     'userSlug': '',
#     'userRatingAverage': '4.9',
#     'userCourseReviewCount': 311},
#    {'id': 84993,
#     'star': 5,
#     'body': '좋은 강의 감사합니다.',
#     'userName': '김성현',
#     'createdAt': '2022-04-17 03:24:37',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 395672,
#     'lectureProgress': '100.00',
#     'postId': 510650,
#     'userSlug': '',
#     'userRatingAverage': '4.9',
#     'userCourseReviewCount': 39},
#    {'id': 84315,
#     'star': 5,
#     'body': '아주 좋습니다',
#     'userName': '김대현',
#     'createdAt': '2022-04-12 11:39:43',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 897701,
#     'lectureProgress': '96.97',
#     'postId': 505002,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 1},
#    {'id': 78994,
#     'star': 5,
#     'body': '재밌습니다!',
#     'userName': '980513k',
#     'createdAt': '2022-03-02 19:05:45',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 689136,
#     'lectureProgress': '7.58',
#     'postId': 461753,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 124},
#    {'id': 71541,
#     'star': 5,
#     'body': '좋았습니다',
#     'userName': '권일근',
#     'createdAt': '2022-01-13 19:13:39',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 163848,
#     'lectureProgress': '100.00',
#     'postId': 399388,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 12},
#    {'id': 70526,
#     'star': 5,
#     'body': '이제 막 처음 배우기 시작해서 막막했는데 큰 틀을 이해하기에 너무 좋았습니다. 감사합니다.',
#     'userName': 'qiglwy95',
#     'createdAt': '2022-01-07 19:29:59',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 442685,
#     'lectureProgress': '100.00',
#     'postId': 390684,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 5},
#    {'id': 69120,
#     'star': 5,
#     'body': '필요한 설명한 진행해서  집중이 잘됩니다.',
#     'userName': 'ccy7774',
#     'createdAt': '2021-12-29 10:43:09',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 593034,
#     'lectureProgress': '100.00',
#     'postId': 379382,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 3},
#    {'id': 67858,
#     'star': 5,
#     'body': '거를 타선이 없는 깔끔한 강의입니다.\n이런 고급진 강의가 무료라는 것에 감동을 표합니다.\n잘 들었습니다.',
#     'userName': '즈르릉',
#     'createdAt': '2021-12-19 14:48:02',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 684854,
#     'lectureProgress': '22.73',
#     'postId': 371170,
#     'userSlug': 'helloworld2222',
#     'userRatingAverage': '4.6',
#     'userCourseReviewCount': 10},
#    {'id': 65482,
#     'star': 5,
#     'body': '감사합니다 잘들었습니다',
#     'userName': '할수있다',
#     'createdAt': '2021-11-26 23:50:05',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 137208,
#     'lectureProgress': '100.00',
#     'postId': 356947,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 327},
#    {'id': 64436,
#     'star': 5,
#     'body': '프로그래밍 경험이있는 사람이 풀스택개발에 관심이있다면 빠르면 3~4일만에 완강하실 수 있습니다. 친절한 설명과 공감되는 코멘트 덕에 웃으면서 공부했네요. 단계별로 보면서 같이 코딩하니 이해도 잘되었습니다. 마지막에 다시 돌아와서 볼 수 있게 요약도해주는 좋은 강의에요.',
#     'userName': 'mslim1210',
#     'createdAt': '2021-11-16 20:32:20',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 664089,
#     'lectureProgress': '96.97',
#     'postId': 351008,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 12},
#    {'id': 54854,
#     'star': 5,
#     'body': '전반적인 흐름에 대해서 알 수 있었습니다',
#     'userName': 'andthensome',
#     'createdAt': '2021-08-16 20:59:45',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 243687,
#     'lectureProgress': '12.12',
#     'postId': 285503,
#     'userSlug': 'balparang',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 337},
#    {'id': 54274,
#     'star': 5,
#     'body': '감사합니다.',
#     'userName': 'jeris',
#     'createdAt': '2021-08-11 17:26:22',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 75687,
#     'lectureProgress': '100.00',
#     'postId': 281690,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 3},
#    {'id': 52549,
#     'star': 5,
#     'body': '웹 개발의 전반적인 흐름을 이해할 수 있어서 좋았습니다.',
#     'userName': '꿀잼사슴',
#     'createdAt': '2021-07-27 12:57:26',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 490778,
#     'lectureProgress': '100.00',
#     'postId': 267644,
#     'userSlug': 'letskirill',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 15},
#    {'id': 50145,
#     'star': 5,
#     'body': '차근차근 알려줘서 공부하기 너무 좋아요',
#     'userName': '전영준',
#     'createdAt': '2021-07-07 15:07:43',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 592731,
#     'lectureProgress': '100.00',
#     'postId': 249910,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 1},
#    {'id': 50114,
#     'star': 5,
#     'body': '기본 공부하기에 너무 유익합니다.\n감사합니다.',
#     'userName': 'usakangla',
#     'createdAt': '2021-07-07 03:58:50',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 587071,
#     'lectureProgress': '30.30',
#     'postId': 249592,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 2},
#    {'id': 49461,
#     'star': 5,
#     'body': '무료 강의인데도 너무 만족스럽고 꽉찬 강의입니다. 정말 감사합니다',
#     'userName': '이동호',
#     'createdAt': '2021-07-01 13:32:51',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 588754,
#     'lectureProgress': '43.94',
#     'postId': 243911,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 1},
#    {'id': 49323,
#     'star': 5,
#     'body': '관심있는 강의만 들었습니다. 좋은 강의인 것 같습니다.',
#     'userName': '이의종',
#     'createdAt': '2021-06-30 14:42:47',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 72872,
#     'lectureProgress': '21.21',
#     'postId': 242944,
#     'userSlug': '',
#     'userRatingAverage': '4.9',
#     'userCourseReviewCount': 12},
#    {'id': 48755,
#     'star': 5,
#     'body': '도움이 많이 되었어요',
#     'userName': 'jalanee',
#     'createdAt': '2021-06-25 15:59:44',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 584697,
#     'lectureProgress': '100.00',
#     'postId': 238806,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 3},
#    {'id': 46613,
#     'star': 5,
#     'body': 'html, php, javascript, css 등 처음 입문하기에 좋은 강의입니다. 감사합니다',
#     'userName': '이한나',
#     'createdAt': '2021-06-02 22:27:54',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 159569,
#     'lectureProgress': '100.00',
#     'postId': 224473,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 1},
#    {'id': 44451,
#     'star': 5,
#     'body': '항상 좋은 강의 들으면 수업하고 있습니다. 영상이 많아서 너무 좋습니다',
#     'userName': '곰훈',
#     'createdAt': '2021-05-11 22:57:21',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 50569,
#     'lectureProgress': '43.94',
#     'postId': 211375,
#     'userSlug': '',
#     'userRatingAverage': '4.5',
#     'userCourseReviewCount': 4},
#    {'id': 42534,
#     'star': 5,
#     'body': '너무나도 혜자인 것',
#     'userName': '토모시키',
#     'createdAt': '2021-04-21 16:57:36',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 95444,
#     'lectureProgress': '89.39',
#     'postId': 198180,
#     'userSlug': 'tomosiki',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 8},
#    {'id': 42431,
#     'star': 5,
#     'body': '선생님 수업 정말 좋아요~ 근데 답변이 늦을까 봐 걱정이 되네요~  수고하세요',
#     'userName': '헐레벌떡 김경미 ',
#     'createdAt': '2021-04-20 17:23:41',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 439319,
#     'lectureProgress': '34.85',
#     'postId': 197398,
#     'userSlug': 'loveje',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 45},
#    {'id': 41450,
#     'star': 5,
#     'body': '무작정 만들어보고 싶어서 강의 엄청 찾아봤는데 사막에 오아시스 처럼 이 강의가 나타났습니다.... 입문자에게 너무나도 큰 도움을 주는 강의들이라 강력 추천드려요',
#     'userName': 'rma7',
#     'createdAt': '2021-04-10 18:30:36',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 384940,
#     'lectureProgress': '96.97',
#     'postId': 190509,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 5},
#    {'id': 41395,
#     'star': 5,
#     'body': '개발을 처음 접하는 지라 두려움이 많았는데 한강의 한강의 공부하면서 재미를 느끼고 있어요. 좋은 강의 감사합니다~~♡',
#     'userName': 'sonamoo__',
#     'createdAt': '2021-04-09 21:28:25',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 435508,
#     'lectureProgress': '63.64',
#     'postId': 189846,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 1},
#    {'id': 40885,
#     'star': 5,
#     'body': '정말 최고입니다! 비전공자도, 프로그래밍 잘 모르는 사람도 잘 이해할 수 있도록 친절하게 알려주셔서 정말 편해요!',
#     'userName': 'Masa',
#     'createdAt': '2021-04-05 14:22:15',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 464250,
#     'lectureProgress': '87.88',
#     'postId': 186356,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 1},
#    {'id': 39788,
#     'star': 5,
#     'body': '매우 훌륭한 과정입니다.',
#     'userName': 'goodphs',
#     'createdAt': '2021-03-26 12:44:18',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 451901,
#     'lectureProgress': '100.00',
#     'postId': 180081,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 1},
#    {'id': 39458,
#     'star': 5,
#     'body': '훌륭합니다',
#     'userName': 'goodlink2013',
#     'createdAt': '2021-03-23 15:52:18',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 458801,
#     'lectureProgress': '60.61',
#     'postId': 178037,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 1},
#    {'id': 36778,
#     'star': 5,
#     'body': '웹을 이해할 때 정말 좋은 강의',
#     'userName': '친환경사과',
#     'createdAt': '2021-02-25 12:53:32',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 432703,
#     'lectureProgress': '81.82',
#     'postId': 160386,
#     'userSlug': 'ecofriendlyapplesu',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 5},
#    {'id': 30888,
#     'star': 5,
#     'body': '초보가 이해하기에 쉽습니다!',
#     'userName': 'Myungwoo LEE',
#     'createdAt': '2020-12-31 15:59:01',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 340652,
#     'lectureProgress': '62.12',
#     'postId': 115446,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 1},
#    {'id': 30623,
#     'star': 5,
#     'body': '쉽게 기본부터 도움을 줘서 좋아요',
#     'userName': '윤정훈',
#     'createdAt': '2020-12-29 16:22:02',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 141489,
#     'lectureProgress': '39.39',
#     'postId': 113701,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 8},
#    {'id': 30515,
#     'star': 5,
#     'body': '짱이에요 감사합니다 !!!',
#     'userName': '김경민',
#     'createdAt': '2020-12-28 23:37:24',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 404710,
#     'lectureProgress': '93.94',
#     'postId': 113026,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 3},
#    {'id': 30160,
#     'star': 5,
#     'body': '강의덕분에 두려움 없이 웹공부를 할 수 있는것 같아요. 감사합니다.',
#     'userName': 'Kyungwon Kang',
#     'createdAt': '2020-12-26 13:44:09',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 369736,
#     'lectureProgress': '87.88',
#     'postId': 111027,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 1},
#    {'id': 29616,
#     'star': 5,
#     'body': '너무 도움이 많이되요 감사합니다.',
#     'userName': 'Prov',
#     'createdAt': '2020-12-21 13:25:49',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/users/thumbnails/407531/ee02260f-b909-4db1-91fc-b48b2bd696b5',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 407531,
#     'lectureProgress': '39.39',
#     'postId': 107621,
#     'userSlug': 'herman',
#     'userRatingAverage': '4.0',
#     'userCourseReviewCount': 4},
#    {'id': 28090,
#     'star': 5,
#     'body': '좋은 강의 감사합니다. 업무에 많은 도움이 되겠습니다.',
#     'userName': 'jeja21cc',
#     'createdAt': '2020-12-02 23:32:04',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 380898,
#     'lectureProgress': '100.00',
#     'postId': 98407,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 3},
#    {'id': 26328,
#     'star': 5,
#     'body': '좋은 강의였습니다',
#     'userName': 'bwor war',
#     'createdAt': '2020-11-10 17:13:07',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 110288,
#     'lectureProgress': '100.00',
#     'postId': 89656,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 1},
#    {'id': 26150,
#     'star': 5,
#     'body': '선생님 수업 잘 듣고 있습니다. 수업이 5분-10분정도로 짧게 나누어져 있어서 이걸 언제 다듣나...하고 막막하지도 않고 설명을 너무 잘해주셔서 이해도 쏙쏙 잘 되고 너무 재미있어요! 퇴근 후에 피곤해서 아무것도 하기 싫은데 강의가 재미있어서 컴퓨터를 키게됩니다! 어서 강의 완강해서 웹에플리케이션을 만들고 싶어요! 완강까지 화이팅입니다~!!',
#     'userName': 'Solar',
#     'createdAt': '2020-11-08 16:24:57',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 393199,
#     'lectureProgress': '96.97',
#     'postId': 88561,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 2},
#    {'id': 25808,
#     'star': 5,
#     'body': '믿고 듣는 생활코딩 강의!',
#     'userName': 'Carrie Choi',
#     'createdAt': '2020-11-03 17:56:59',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 262853,
#     'lectureProgress': '6.06',
#     'postId': 86380,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 17},
#    {'id': 24142,
#     'star': 5,
#     'body': '이게 무료라고..????????????????????????????????????????????????????????????????????????????????????????????????이게 무료라고..????????????????????????????????????????????????????????????????????????????????????????????????이게 무료라고..????????????????????????????????????????????????????????????????????????????????????????????????이게 무료라고..????????????????????????????????????????????????????????????????????????????????????????????????이게 무료라고..????????????????????????????????????????????????????????????????????????????????????????????????이게 무료라고..????????????????????????????????????????????????????????????????????????????????????????????????이게 무료라고..????????????????????????????????????????????????????????????????????????????????????????????????이게 무료라고..????????????????????????????????????????????????????????????????????????????????????????????????이게 무료라고..????????????????????????????????????????????????????????????????????????????????????????????????이게 무료라고..????????????????????????????????????????????????????????????????????????????????????????????????이게 무료라고..????????????????????????????????????????????????????????????????????????????????????????????????이게 무료라고..????????????????????????????????????????????????????????????????????????????????????????????????이게 무료라고..????????????????????????????????????????????????????????????????????????????????????????????????이게 무료라고..????????????????????????????????????????????????????????????????????????????????????????????????이게 무료라고..????????????????????????????????????????????????????????????????????????????????????????????????이게 무료라고..????????????????????????????????????????????????????????????????????????????????????????????????이게 무료라고..????????????????????????????????????????????????????????????????????????????????????????????????이게 무료라고..????????????????????????????????????????????????????????????????????????????????????????????????이게 무료라고..????????????????????????????????????????????????????????????????????????????????????????????????이게 무료라고..????????????????????????????????????????????????????????????????????????????????????????????????이게 무료라고..????????????????????????????????????????????????????????????????????????????????????????????????이게 무료라고..????????????????????????????????????????????????????????????????????????????????????????????????이게 무료라고..????????????????????????????????????????????????????????????????????????????????????????????????이게 무료라고..????????????????????????????????????????????????????????????????????????????????????????????????이게 무료라고..????????????????????????????????????????????????????????????????????????????????????????????????이게 무료라고..????????????????????????????????????????????????????????????????????????????????????????????????이게 무료라고..????????????????????????????????????????????????????????????????????????????????????????????????',
#     'userName': 'i71065g7 (탈퇴)',
#     'createdAt': '2020-10-12 10:06:26',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 383551,
#     'lectureProgress': '57.58',
#     'postId': 76360,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 9},
#    {'id': 23739,
#     'star': 5,
#     'body': '비전공자라서 어디부터 시작해야할지 막막하고 몰랐는데 차근차근알려주셔서 너무 좋았어요.',
#     'userName': 'sef951',
#     'createdAt': '2020-10-06 10:59:13',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 374904,
#     'lectureProgress': '98.48',
#     'postId': 73661,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 1},
#    {'id': 23636,
#     'star': 5,
#     'body': '너무 유익합니다~! 존경합니다.',
#     'userName': 'Aurora',
#     'createdAt': '2020-10-04 16:03:02',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 213677,
#     'lectureProgress': '81.82',
#     'postId': 72810,
#     'userSlug': '',
#     'userRatingAverage': '4.9',
#     'userCourseReviewCount': 41},
#    {'id': 17708,
#     'star': 5,
#     'body': '처음으로 웹을 공부하기위해 들었는데 정말 많은 도움이 되었고 html js css php에 대해 기초를 알 수 있었습니다.',
#     'userName': 'youuy28',
#     'createdAt': '2020-06-15 17:29:53',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 329442,
#     'lectureProgress': '100.00',
#     'postId': 38416,
#     'userSlug': '',
#     'userRatingAverage': '4.9',
#     'userCourseReviewCount': 8},
#    {'id': 16718,
#     'star': 5,
#     'body': '설명이 정말 잘 되어있어요!',
#     'userName': '영쭈',
#     'createdAt': '2020-05-25 11:56:36',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 22846,
#     'lectureProgress': '100.00',
#     'postId': 36190,
#     'userSlug': '',
#     'userRatingAverage': '3.8',
#     'userCourseReviewCount': 6},
#    {'id': 15676,
#     'star': 5,
#     'body': '감사합니다. 저같은 타전공 학생이 컴퓨터에 관심이 있어서 교육받을 수 있다는 것에 정말 감사드립니다.',
#     'userName': '박세웅',
#     'createdAt': '2020-04-30 22:04:23',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/users/thumbnails/300172/ba4c07cf-8e1b-4c19-98fe-5ba00badbce9',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 300172,
#     'lectureProgress': '100.00',
#     'postId': 33344,
#     'userSlug': '',
#     'userRatingAverage': '4.7',
#     'userCourseReviewCount': 3},
#    {'id': 13581,
#     'star': 5,
#     'body': '자세한 설명으로 초보자도 용이하게 접근이 가능하네요..추천합니다.^^',
#     'userName': 'Youngjae Heo',
#     'createdAt': '2020-03-21 23:02:55',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 296398,
#     'lectureProgress': '7.58',
#     'postId': 28780,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 1},
#    {'id': 11235,
#     'star': 5,
#     'body': '웹어플리케이션을 만드는 전체과정을 이해하는데 많은 도움이 되었어요~',
#     'userName': 'Eddy Chang',
#     'createdAt': '2020-01-21 18:19:52',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 62951,
#     'lectureProgress': '100.00',
#     'postId': 22355,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 1},
#    {'id': 11143,
#     'star': 5,
#     'body': '최고!! 큰 도움이 되었어요!!',
#     'userName': '이정배',
#     'createdAt': '2020-01-17 17:45:14',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 175624,
#     'lectureProgress': '100.00',
#     'postId': 21991,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 1},
#    {'id': 11107,
#     'star': 5,
#     'body': '한 번에 전체적인 구조를 이해하기 쉬워요',
#     'userName': '황현정',
#     'createdAt': '2020-01-16 08:44:56',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 223013,
#     'lectureProgress': '90.91',
#     'postId': 21840,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 1},
#    {'id': 7131,
#     'star': 5,
#     'body': '원론적인 부분부터 실질적인 부분까지 무엇하나 빠지는게 없습니다 \n목소리도 너무 편안해서 좋았어요 다만 인프런에 의도하신건지 모르겠지만  한두 단원이 누락되어 있어(아마 초보 강의라 일부러 빼셨는지 모르겠지만) 자세히 듣고 싶으시다면 생활코딩 홈페이지에서 누락부분을 확인하세요',
#     'userName': '김상훈',
#     'createdAt': '2019-07-09 22:19:20',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 69859,
#     'lectureProgress': '0.00',
#     'postId': 11113,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 1},
#    {'id': 6922,
#     'star': 5,
#     'body': '편안한 목소리로 설명을 잘해주십니다',
#     'userName': 'Bed reven',
#     'createdAt': '2019-06-29 18:35:19',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 179307,
#     'lectureProgress': '0.00',
#     'postId': 10714,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 1},
#    {'id': 5737,
#     'star': 5,
#     'body': '좋은 강의 감사합니다\n무료로 이런 수준의 강의를 들을 수 있다니 믿기지 않네요 세상이 참 좋아졌다고만 하기 보다는 이고잉 강사님  노력에 감사의 박수를 보내고 싶습니다. 감사합니다.',
#     'userName': 'Peter Byun',
#     'createdAt': '2019-04-03 17:02:46',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 140958,
#     'lectureProgress': '71.21',
#     'postId': 8282,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 7},
#    {'id': 5736,
#     'star': 5,
#     'body': '좋은 강의 감사합니다\n무료로 이런 수준의 강의를 들을 수 있다니 믿기지 않네요 세상이 참 좋아졌다고만 하기보다는 이고잉 강사님  노력에 감사의 박수를 보내고 싶습니다. 감사합니다.',
#     'userName': 'Peter Byun',
#     'createdAt': '2019-04-03 17:02:22',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 140958,
#     'lectureProgress': '71.21',
#     'postId': 8281,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 7},
#    {'id': 5719,
#     'star': 5,
#     'body': '알기 쉽게, 마음은 가볍게. \n저같은 초보도 이해하기 쉽도록 설명해 주셔서 감사합니다. \r\n무엇보다 수강자의 마음을 가볍게 해주는 멘트들이 있어서 \r\n부담은 덜고 더 재밌고 즐겁게 수강할 수 있었습니다. \r\n정말 감사합니다!!',
#     'userName': '석선우',
#     'createdAt': '2019-04-01 18:39:53',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 137707,
#     'lectureProgress': '100.00',
#     'postId': 8248,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 1},
#    {'id': 5024,
#     'star': 5,
#     'body': '기초 다지기에 좋은 강의였습니다.\n밑거름이 되리라 믿으면서 다음 강좌 계속 갑니다.',
#     'userName': '망포런',
#     'createdAt': '2019-01-03 20:42:48',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 141058,
#     'lectureProgress': '54.55',
#     'postId': 6837,
#     'userSlug': '',
#     'userRatingAverage': '4.5',
#     'userCourseReviewCount': 2},
#    {'id': 4480,
#     'star': 4,
#     'body': '감사합니다!!\n좋은 강의 감사합니다! 행복하세요!',
#     'userName': '서진영',
#     'createdAt': '2018-10-23 22:56:29',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 119691,
#     'lectureProgress': '18.18',
#     'postId': 5812,
#     'userSlug': '',
#     'userRatingAverage': '4.3',
#     'userCourseReviewCount': 8},
#    {'id': 4031,
#     'star': 5,
#     'body': '입문자에게 최고의 강의!\n웹 프로그래밍 입문 강좌로서 이만한 강좌는 거의 없다고 생각합니다.\r\n\r\n웹의 본질과 학습 방향성 그리고 다양하고 꼭 필요한 개념들을 이 강좌 하나로 모두 만나보실 수 있습니다.\r\n웹을 처음 공부하는 저로서는 굉장히 좋은 강의를 들을 수 있게 되어 영광이었습니다.\r\n좋은 강의 만들어 주셔서 굉장히 고맙습니다.',
#     'userName': '흑구',
#     'createdAt': '2018-08-07 15:27:15',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/wp-content/uploads/avatars/78516/5bdec5fa4eedb-bpfull.jpg',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 78516,
#     'lectureProgress': '86.36',
#     'postId': 4792,
#     'userSlug': '',
#     'userRatingAverage': '4.9',
#     'userCourseReviewCount': 16},
#    {'id': 2741,
#     'star': 5,
#     'body': '최고!',
#     'userName': 'mello',
#     'createdAt': '2018-01-10 21:39:43',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 59776,
#     'lectureProgress': '84.85',
#     'postId': 2632,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 2},
#    {'id': 2229,
#     'star': 5,
#     'body': '최고에요~~~!!!!!\n정말 최고에요~~!!!!!',
#     'userName': '규민',
#     'createdAt': '2017-10-11 22:09:57',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 62045,
#     'lectureProgress': '100.00',
#     'postId': 2091,
#     'userSlug': 'wannabmc',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 4},
#    {'id': 1951,
#     'star': 5,
#     'body': '나도 언젠가 코딩강의를 하게 된다면\n이 사람처럼 이야기해주고,\r\n이 사람처럼 가르치고 싶다.\r\n욕심을 조금만 내려놓는다면...\r\n이 사람의 강의를 추천해줄 거고ㅋ\r\n\r\n감사합니다.',
#     'userName': '일코',
#     'createdAt': '2017-08-14 15:45:00',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/users/thumbnails/52376/4b4d420f-438e-4dd3-9f3b-678fa1ef693e',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 52376,
#     'lectureProgress': '27.27',
#     'postId': 1673,
#     'userSlug': 'martiniifun',
#     'userRatingAverage': '4.9',
#     'userCourseReviewCount': 18},
#    {'id': 1866,
#     'star': 5,
#     'body': '기초다지기에 좋아요\n처음 공부하는 웹프로그래밍인데 굉장히 친절하게 설명해주셔서 많은 도움이 된거같습니다.',
#     'userName': '조승우',
#     'createdAt': '2017-07-25 16:42:53',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 38754,
#     'lectureProgress': '100.00',
#     'postId': 1525,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 1},
#    {'id': 1813,
#     'star': 5,
#     'body': '정말 대단하신 선생님\n너무너무 감사합니다 정말 힘들어서 아직도 이해가 잘 가지 않는 부분이 많지만 분명 얻어가는 것이 있을 것이라고 믿습니다\r\n잘 배웠습니다 !',
#     'userName': '이예찬 이',
#     'createdAt': '2017-07-13 00:18:00',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 37334,
#     'lectureProgress': '100.00',
#     'postId': 1437,
#     'userSlug': '',
#     'userRatingAverage': '5.0',
#     'userCourseReviewCount': 1},
#    {'id': 1430,
#     'star': 5,
#     'body': '따라하면서 배우는 웹애플리케이션 만들기\n이론을 정리하려고 다시 기초부터 보았습니다. 좋은 강의 입니다.',
#     'userName': '수지아빠',
#     'createdAt': '2017-04-02 18:05:32',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 30710,
#     'lectureProgress': '100.00',
#     'postId': 1048,
#     'userSlug': '',
#     'userRatingAverage': '4.9',
#     'userCourseReviewCount': 12},
#    {'id': 679,
#     'star': 5,
#     'body': '두번째 완강했습니다!\n보면 볼수록 재밌습니다.\r\n\r\n불필요한 것들은 제외하고 꼭 알아야 할 것들만 꼭꼭 집어서 알려주시니 머리에 정리가 잘 되는거 같습니다.\r\n\r\n계속해서 더 많은 강의 들어보겠습니다.',
#     'userName': '너굴너굴너구리',
#     'createdAt': '2016-01-09 18:55:31',
#     'recommendCount': 0,
#     'userThumbnailUrl': 'https://cdn.inflearn.com/public/main/profile/default_profile.png',
#     'isRecommended': False,
#     'isEditable': False,
#     'comments': [],
#     'userId': 597,
#     'lectureProgress': '51.52',
#     'postId': 15,
#     'userSlug': 'parkpresent',
#     'userRatingAverage': '4.8',
#     'userCourseReviewCount': 10}]}}
